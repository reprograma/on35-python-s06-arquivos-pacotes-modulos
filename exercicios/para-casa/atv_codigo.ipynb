# %%
import pandas as pd

# %%
tabela = pd.read_excel("atv-casa.xlsx") #Poderia ter , sheet_name=0 para indicar que é a primeira aba
display(tabela)
# Out:
#         Nome  Sobrenome  Nota 1Bimestre  Nota 2Bimestre  Nota 3Bimestre  \
# 0    Eduardo  Rodrigues               6               9               6
# 1     Carlos      Souza               5               3               0
# 2     Helena       Lima               9               7               3
# 3        Ana    Almeida               6               7               7
# 4   Fernanda   Oliveira               6               4               8
# 5       Igor   Carvalho               4               8               6
# 6      Alice    Pereira               3               3               7
# 7  Valentina    Almeida               6               9              10
# 8       Enzo      Silva               6               8               9
# 9      Bruno     Santos               7              10               9
#
#    Faltas 1Bimestre  Faltas 2Bimestre  Faltas 3Bimestre
# 0                 1                 1                 1
# 1                 1                 4                 3
# 2                 1                 4                 2
# 3                 1                 5                 3
# 4                 0                 1                 1
# 5                 3                 3                 3
# 6                 0                 3                 7
# 7                 1                 5                 1
# 8                 4                 2                 0
# 9                 3                 2                 0

# %%
tabela = pd.read_excel("atv-casa.xlsx", sheet_name=1)#segunda aba
display(tabela)
# Out:
#        Nome  Sobrenome  Nota 1Bimestre  Nota 2Bimestre  Nota 3Bimestre  \
# 0     Laura      Gomes               8               6               7
# 1    Rafael      Costa               5               4               6
# 2   Beatriz    Moreira               7               9               8
# 3      João     Mendes               4               6               5
# 4   Vitória    Barbosa              10               9               9
# 5   Gabriel   Ferreira               6               7               5
# 6   Mariana      Rocha               5               5               7
# 7  Henrique       Lima               8               6               8
# 8     Júlia    Martins               7               8               7
# 9   Matheus  Fernandes               9               7              10
#
#    Faltas 1Bimestre  Faltas 2Bimestre  Faltas 3Bimestre
# 0                 2                 1                 0
# 1                 3                 2                 1
# 2                 1                 1                 1
# 3                 2                 3                 2
# 4                 0                 0                 0
# 5                 2                 4                 3
# 6                 1                 2                 2
# 7                 1                 0                 1
# 8                 0                 1                 0
# 9                 1                 2                 0

# %%
tabela = pd.read_excel("atv-casa.xlsx", sheet_name='notas_t2')
display(tabela)
# Out:
#        Nome  Sobrenome  Nota 1Bimestre  Nota 2Bimestre  Nota 3Bimestre  \
# 0     Laura      Gomes               8               6               7
# 1    Rafael      Costa               5               4               6
# 2   Beatriz    Moreira               7               9               8
# 3      João     Mendes               4               6               5
# 4   Vitória    Barbosa              10               9               9
# 5   Gabriel   Ferreira               6               7               5
# 6   Mariana      Rocha               5               5               7
# 7  Henrique       Lima               8               6               8
# 8     Júlia    Martins               7               8               7
# 9   Matheus  Fernandes               9               7              10
#
#    Faltas 1Bimestre  Faltas 2Bimestre  Faltas 3Bimestre
# 0                 2                 1                 0
# 1                 3                 2                 1
# 2                 1                 1                 1
# 3                 2                 3                 2
# 4                 0                 0                 0
# 5                 2                 4                 3
# 6                 1                 2                 2
# 7                 1                 0                 1
# 8                 0                 1                 0
# 9                 1                 2                 0

# %%
#Selecionando as colunas pelo nome da "coluna"
tabela = pd.read_excel("atv-casa.xlsx", sheet_name='notas_t2',usecols="A:H")
display(tabela)
# Out:
#        Nome  Sobrenome  Nota 1Bimestre  Nota 2Bimestre  Nota 3Bimestre  \
# 0     Laura      Gomes               8               6               7
# 1    Rafael      Costa               5               4               6
# 2   Beatriz    Moreira               7               9               8
# 3      João     Mendes               4               6               5
# 4   Vitória    Barbosa              10               9               9
# 5   Gabriel   Ferreira               6               7               5
# 6   Mariana      Rocha               5               5               7
# 7  Henrique       Lima               8               6               8
# 8     Júlia    Martins               7               8               7
# 9   Matheus  Fernandes               9               7              10
#
#    Faltas 1Bimestre  Faltas 2Bimestre  Faltas 3Bimestre
# 0                 2                 1                 0
# 1                 3                 2                 1
# 2                 1                 1                 1
# 3                 2                 3                 2
# 4                 0                 0                 0
# 5                 2                 4                 3
# 6                 1                 2                 2
# 7                 1                 0                 1
# 8                 0                 1                 0
# 9                 1                 2                 0

# %%
#Pegando todas as informações de um arquivo
tabela = pd.read_excel("atv-casa.xlsx", sheet_name=None)#todas as informações de toda planilha (todas as abas)
display(tabela)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #Pegando todas as informações de um arquivo
#       2 tabela = pd.read_excel("atv-casa.xlsx", sheet_name=None)#todas as informações de toda planilha (todas as abas)
# ----> 3 display(tabela,ignore_index=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\display_functions.py:305, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     302         if metadata:
#     303             # kwarg-specified metadata gets precedence
#     304             _merge(md_dict, metadata)
# --> 305         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     306 if display_id:
#     307     return DisplayHandle(display_id)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\display_functions.py:93, in publish_display_data(data, metadata, source, transient, **kwargs)
#      90 if transient:
#      91     kwargs['transient'] = transient
# ---> 93 display_pub.publish(
#      94     data=data,
#      95     metadata=metadata,
#      96     **kwargs
#      97 )
#
# TypeError: ZMQDisplayPublisher.publish() got an unexpected keyword argument 'ignore_index'

# %%
#Pegar determinada quantidade de linhas
tabela = pd.read_excel("atv-casa.xlsx", sheet_name="notas_t1",skiprows=7)#aba notas_t1 e pula/desconsidera 7 linhas
display(tabela)
# Out:
#        Alice  Pereira  3  3.1   7  0  3.2  7.1
# 0  Valentina  Almeida  6    9  10  1    5    1
# 1       Enzo    Silva  6    8   9  4    2    0
# 2      Bruno   Santos  7   10   9  3    2    0

# %%
#Pular linhas
tabela = pd.read_excel("atv-casa.xlsx", sheet_name="notas_t1",nrows=11)#aba notas_t1 e pula/desconsidera 7 linhas
display(tabela)
# Out:
#         Nome  Sobrenome  Nota 1Bimestre  Nota 2Bimestre  Nota 3Bimestre  \
# 0    Eduardo  Rodrigues               6               9               6
# 1     Carlos      Souza               5               3               0
# 2     Helena       Lima               9               7               3
# 3        Ana    Almeida               6               7               7
# 4   Fernanda   Oliveira               6               4               8
# 5       Igor   Carvalho               4               8               6
# 6      Alice    Pereira               3               3               7
# 7  Valentina    Almeida               6               9              10
# 8       Enzo      Silva               6               8               9
# 9      Bruno     Santos               7              10               9
#
#    Faltas 1Bimestre  Faltas 2Bimestre  Faltas 3Bimestre
# 0                 1                 1                 1
# 1                 1                 4                 3
# 2                 1                 4                 2
# 3                 1                 5                 3
# 4                 0                 1                 1
# 5                 3                 3                 3
# 6                 0                 3                 7
# 7                 1                 5                 1
# 8                 4                 2                 0
# 9                 3                 2                 0
